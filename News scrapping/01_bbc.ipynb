# %% [markdown]
# # Data Scraping with Python
#
# This notebook demonstrates how to scrape news headlines and their descriptions from the BBC News homepage using Python, `requests`, and `BeautifulSoup`.
#
# **Explanation of the code:**
# - `import requests` and `from bs4 import BeautifulSoup`: Import libraries for HTTP requests and HTML parsing.
# - `news_url = "https://www.bbc.com/news"`: Set the URL for the BBC News homepage.
# - `requests.get(news_url).content`: Fetch the HTML content of the page.
# - `BeautifulSoup(..., "html.parser")`: Parse the HTML content.
# - Try to find all `<h3>` tags with the class `gs-c-promo-heading__title` (common for headlines).
# - If not found, try anchor tags with class `gs-c-promo-heading`.
# - If still not found, fallback to all anchor tags with `/news/` in their `href` and non-empty text.
# - For each headline found, print the headline and its description (if available).
#
# The code is robust to changes in the BBC News HTML structure by trying multiple selectors.

# %% [markdown]
# # Get Headings for headlines

# %%
import requests
from bs4 import BeautifulSoup

# URL for BBC News homepage
news_url = "https://www.bbc.com/news"

# Fetch and parse the page
response = requests.get(news_url)
news_soup = BeautifulSoup(response.content, "html.parser")

# Try multiple selectors for headlines
headlines = news_soup.find_all("h3", class_="gs-c-promo-heading__title")


# If not found, try anchor tags with class 'gs-c-promo-heading'
if not headlines:
    promo_anchors = news_soup.select("a.gs-c-promo-heading")
    headlines = [a for a in promo_anchors if a.text.strip()]

# If still not found, fallback to all anchor tags with '/news/' in href and non-empty text
if not headlines:
    headlines = [
        a for a in news_soup.find_all("a", href=True)
        if "/news/" in a["href"] and a.text.strip()
    ]

if not headlines:
    print("No headlines found using known selectors.")
else:
    for idx, headline in enumerate(headlines, start=1):
        # Get the headline text
        headline_text = headline.text.strip()
        print(f"{idx}. {headline_text}")
# Out:
# 1. Israel-Gaza War
# 2. War in Ukraine
# 3. US & Canada
# 4. UK
# 5. Africa
# 6. Asia
# 7. Australia
# 8. Europe
# 9. Latin America
# 10. Middle East
# 11. In Pictures
# 12. BBC InDepth
# 13. BBC Verify
# 14. Israel-Gaza War
# 15. War in Ukraine
# 16. US & Canada
# 17. UK
# 18. UK Politics
# 19. England
# 20. N. Ireland
# 21. N. Ireland Politics
# 22. Scotland
# 23. Scotland Politics
# 24. Wales
# 25. Wales Politics
# 26. Africa
# 27. Asia
# 28. China
# 29. India
# 30. Australia
# 31. Europe
# 32. Latin America
# 33. Middle East
# 34. In Pictures
# 35. BBC InDepth
# 36. BBC Verify
# 37. LIVEGaza worse than hell on Earth, International Red Cross chief tells BBC as aid centres close for dayThe president of the ICRC tells the BBC's international editor Jeremy Bowen that Palestinians have been stripped of human dignity.
# 38. South Korea's new president has a Trump-shaped crisis to avertLee Jae-myung secured a storming victory, but his honeymoon will barely last the day.13 hrs agoAsia
# 39. The Indian pilot set for a historic space journey on Axiom-4Shubhanshu Shukla will be only the second Indian to travel to space and the first-ever to visit ISS.16 hrs agoWorld
# 40. Vanuatu looks into revoking Andrew Tate's golden passportTate gained citizenship in the tiny Pacific state under a scheme that has allegedly been abused by criminals.8 hrs agoAsia
# 41. Cologne evacuates 20,000 so WW2 bombs can be defusedThe German city cordons off a huge area, calling it the largest evacuation since the end of World War Two.5 hrs agoEurope
# 42. South Korea's new president has a Trump-shaped crisis to avertLee Jae-myung secured a storming victory, but his honeymoon will barely last the day.13 hrs agoAsia
# 43. South Korea's new president Lee Jae-myung pledges to 'unite' countryExperts say he faces a challenging task, as division and discontentment continue to rack South Korea.9 hrs agoAsia
# 44. Deadly mushroom lunch cook tells court she threw up toxic mealErin Patterson is accused of murdering three relatives and trying to kill another with poisonous fungi.6 hrs agoAustralia
# 45. Teen TikTok star shot dead after man broke into her home, police sayThe 17-year-old's murder has sparked a debate about women on social media in Pakistan.2 hrs agoAsia
# 46. The Indian pilot set for a historic space journey on Axiom-4Shubhanshu Shukla will be only the second Indian to travel to space and the first-ever to visit ISS.16 hrs agoWorld
# 47. LIVEUS markets open higher as businesses brace for impact of Trump's 50% metals tariffs
# 48. Musk calls Trump's tax bill a 'disgusting abomination' 3 hrs agoUS & Canada
# 49. Chinese nationals accused of smuggling 'dangerous biological pathogen' into US19 hrs agoWorld
# 50. LIVEBBC Verify Live: New satellite images show damaged Russian bombers from Ukraine attack
# 51. Meghan shares new photos of Lilibet to mark fourth birthday4 hrs agoUK
# 52. Watch: BBC on the ground in Seoul as new president is announcedOpposition's Lee Jae-myung will become South Korea's next president, winning the country's first election since impeachment chaos.19 hrs agoAsia
# 53. Simon Jack: Tariff relief for UK but new clock ticking on US dealIf the UK's deal with the US is not finalised by 9 July, the UK's tariff on steel will go back up to 50%. 4 hrs agoBusiness
# 54. Why Labour is strengthening ties with China after years of rollercoaster relationsTo some, it’s a smart opportunity. To others there are security concerns. But either way, is there a playbook?14 hrs agoBBC InDepth
# 55. Two Scots were shot dead in a busy Spanish bar. Holidaymakers are frightenedBrits on holiday in the Costa del Sol have been shaken by the murder of two senior underworld figures.21 hrs agoScotland
# 56. 'I begged for help, but only God answered': Growing dangers of pregnancy and childbirth in GazaRather than representing the hope of new life, babies in Gaza have come to epitomise the struggle to survive.1 day agoMiddle East
# 57. Simon Jack: Tariff relief for UK but new clock ticking on US dealIf the UK's deal with the US is not finalised by 9 July, the UK's tariff on steel will go back up to 50%. 4 hrs agoBusiness
# 58. On the hunt for Tiger, the fugitive linked to illegal South African gold mine where 78 diedThe BBC tracks down people close to the alleged crime kingpin who escaped custody while awaiting trial.15 hrs agoAfrica
# 59. The Indian pilot set for a historic space journey on Axiom-4Shubhanshu Shukla will be only the second Indian to travel to space and the first-ever to visit ISS.16 hrs agoWorld
# 60. Why Labour is strengthening ties with China after years of rollercoaster relationsTo some, it’s a smart opportunity. To others there are security concerns. But either way, is there a playbook?14 hrs agoBBC InDepth
# 61. 1Watch: Canada wildfire smoke drifts into US and across the Atlantic
# 62. 2Watch: Searching derelict and desolate area in Madeleine McCann case
# 63. 3'We are all going to die' - Senator's healthcare comment sparks row
# 64. 4Nepal's urban rhinos that won't return to the wild
# 65. 5The Today Debate: Israel-Gaza - are we witnessing war crimes?
# 66. Vanuatu looks into revoking Andrew Tate's golden passportTate gained citizenship in the tiny Pacific state under a scheme that has allegedly been abused by criminals.8 hrs agoAsia
# 67. Japanese baseball legend Shigeo Nagashima dies aged 89Known as Mr Giants, Nagashima was one of Japan's most famous sports stars during the 1960s and 70s.1 day agoAsia
# 68. Body found in search for stag party Scot missing in PortugalGreg Monks was reported missing in Albufeira last week after travelling to the resort for a stag party.1 hr agoGlasgow & West Scotland
# 69. India anger over 10-year-old rape victim's death after alleged treatment delayFamily members allege that the girl was kept waiting in an ambulance for hours before being admitted to the hospital.1 day agoAsia
# 70. Kenyan author prosecuted for writing a book about president's daughterCharlene Ruto accused the author of "misusing" her name by writing the book without seeking her permission.4 hrs agoAfrica
# 71. Japanese baseball legend Shigeo Nagashima dies aged 89Known as Mr Giants, Nagashima was one of Japan's most famous sports stars during the 1960s and 70s.1 day agoAsia
# 72. TikTok blocks searches for extreme thinness 'skinnytok' hashtagThe app acknowledged the viral hashtag had been become linked to "unhealthy weight loss content."2 hrs agoTechnology
# 73. Tesla is 'not interested' in producing cars in India - ministerThis is the first time India has publicly admitted that it has not been able to lure investment dollars from Musk. 1 day agoAsia
# 74. Body found in search for stag party Scot missing in PortugalGreg Monks was reported missing in Albufeira last week after travelling to the resort for a stag party.1 hr agoGlasgow & West Scotland
# 75. 1Teen TikTok star shot dead after man broke into her home, police say
# 76. 2Meghan shares new photos of Lilibet to mark fourth birthday
# 77. 3Canada proposes sweeping immigration and security bill
# 78. 4Musk calls Trump's tax bill a 'disgusting abomination'
# 79. 5South Korea's new president has a Trump-shaped crisis to avert
# 80. 6Brits could face death over Bali drugs plot
# 81. 7Vanuatu looks into revoking Andrew Tate's golden passport
# 82. 8Pornhub pulls out of France over age verification law
# 83. 9Deadly mushroom lunch cook tells court she threw up toxic meal
# 84. 10The Indian pilot set for a historic space journey on Axiom-4

# %% [markdown]
# # Other pages

# %%
import requests
from bs4 import BeautifulSoup

# URL for BBC News homepage
news_url = "https://www.bbc.com/sport"

# Fetch and parse the page
response = requests.get(news_url)
news_soup = BeautifulSoup(response.content, "html.parser")

# Try multiple selectors for headlines
headlines = news_soup.find_all("h3", class_="gs-c-promo-heading__title")

# If not found, try anchor tags with class 'gs-c-promo-heading'
if not headlines:
    promo_anchors = news_soup.select("a.gs-c-promo-heading")
    headlines = [a for a in promo_anchors if a.text.strip()]

# If still not found, fallback to all anchor tags with '/news/' in href and non-empty text
if not headlines:
    headlines = [
        a for a in news_soup.find_all("a", href=True)
        if "/news/" in a["href"] and a.text.strip()
    ]

if not headlines:
    print("No headlines found using known selectors.")
else:
    for idx, headline in enumerate(headlines, start=1):
        # Get the headline text
        headline_text = headline.text.strip()
        print(f"{idx}. {headline_text}")
# Out:
# 1. Where and how to watch BBC News
# 2. BBC World News: 24 hour news TV channel

# %%
import requests
from bs4 import BeautifulSoup

# URL for BBC Business page
business_url = "https://www.bbc.com/business"

# Fetch and parse the page
response = requests.get(business_url)
soup = BeautifulSoup(response.content, "html.parser")

# Try to find all headlines (BBC often uses h3 with class 'gs-c-promo-heading__title')
headlines = soup.find_all("h3", class_="gs-c-promo-heading__title")

# If not found, try anchor tags with class 'gs-c-promo-heading'
if not headlines:
    promo_anchors = soup.select("a.gs-c-promo-heading")
    headlines = [a for a in promo_anchors if a.text.strip()]

# If still not found, fallback to all anchor tags with '/business/' in href and non-empty text
if not headlines:
    headlines = [
        a for a in soup.find_all("a", href=True)
        if "/business/" in a["href"] and a.text.strip()
    ]

if not headlines:
    print("No business headlines found using known selectors.")
else:
    for idx, headline in enumerate(headlines, start=1):
        headline_text = headline.text.strip()
        print(f"{idx}. {headline_text}")
# Out:
# 1. Executive Lounge
# 2. Technology of Business
# 3. Future of Business
# 4. Executive Lounge
# 5. Technology of Business
# 6. Future of Business
# 7. World of Business
# 8. NYSE Opening Bell
# 9. Executive Lounge

# %% [markdown]
# # Download BBC news headlines with links and snippets

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime

# URL for BBC News homepage
news_url = "https://www.bbc.com/news"

# Fetch and parse the page
response = requests.get(news_url)
news_soup = BeautifulSoup(response.content, "html.parser")

# Try multiple selectors for headlines
headlines = news_soup.find_all("h3", class_="gs-c-promo-heading__title")

# If not found, try anchor tags with class 'gs-c-promo-heading'
if not headlines:
    promo_anchors = news_soup.select("a.gs-c-promo-heading")
    headlines = [a for a in promo_anchors if a.text.strip()]

# If still not found, fallback to all anchor tags with '/news/' in href and non-empty text
if not headlines:
    headlines = [
        a for a in news_soup.find_all("a", href=True)
        if "/news/" in a["href"] and a.text.strip()
    ]

if not headlines:
    print("No headlines found using known selectors.")
else:
    for idx, headline in enumerate(headlines, start=1):
        # Get the headline text and link
        headline_text = headline.text.strip()
        # Try to get the URL from the parent anchor or from the tag itself
        link = None
        if headline.name == "a" and headline.has_attr("href"):
            link = headline["href"]
        else:
            parent_a = headline.find_parent("a", href=True)
            if parent_a:
                link = parent_a["href"]
        # Make sure the link is absolute
        if link and link.startswith("/"):
            link = "https://www.bbc.com" + link
        # Print headline
        print(f"{idx}. {headline_text}")
        if link:
            print(f"   Link: {link}")
            # Fetch the news article page
            try:
                article_resp = requests.get(link)
                article_soup = BeautifulSoup(article_resp.content, "html.parser")
                # Try to extract all paragraphs in the article body
                # BBC often uses <article> tag or role="main"
                article_tag = article_soup.find("article")
                if not article_tag:
                    article_tag = article_soup.find(attrs={"role": "main"})
                if article_tag:
                    paragraphs = article_tag.find_all("p")
                else:
                    paragraphs = article_soup.find_all("p")
                # Combine the text of all paragraphs
                article_text = " ".join([p.get_text(strip=True) for p in paragraphs])
                # Print a snippet (first 400 chars)
                snippet = article_text[:400] + ("..." if len(article_text) > 400 else "")
                # Try to extract date and time
                date_str = ""
                # Look for <time> tag with datetime attribute
                time_tag = article_soup.find("time")
                if not time_tag:
                    # Try to find meta tag with property 'article:published_time'
                    meta_time = article_soup.find("meta", attrs={"property": "article:published_time"})
                    if meta_time and meta_time.has_attr("content"):
                        date_str = meta_time["content"]
                if not date_str and time_tag and time_tag.has_attr("datetime"):
                    date_str = time_tag["datetime"]
                elif not date_str and time_tag:
                    date_str = time_tag.get_text(strip=True)
                if date_str:
                    try:
                        dt = datetime.fromisoformat(date_str.replace("Z", "+00:00"))
                        date_str = dt.strftime("%Y-%m-%d %H:%M:%S %Z")
                    except Exception:
                        pass
                print(f"   Date: {date_str if date_str else '(No date found)'}")
                print(f"   News: {snippet}")
            except Exception as e:
                print(f"   Date: (No date found)")
                print(f"   News: (Could not fetch article: {e})")
        else:
            print("   Link: (No link found)")
            print("   Date: (No date found)")
            print("   News: (No article found)")
# Out:
# 1. Israel-Gaza War
#    Link: https://www.bbc.com/news/topics/c2vdnvdg6xxt
#    Date: (No date found)
#    News: Aid distribution will be halted on Wednesday, with Gazans warned by the IDF not to travel to collection points. Civilians were fired at by tanks, drones and helicopters, civil defence officials say, while Israel says only that troops fired towards several suspects. Hamdi al-Najjar's wife and 11-year-old son Adam, who was severely injured, are the only survivors in their family. Reports say an inci...
# 2. War in Ukraine
#    Link: https://www.bbc.com/news/war-in-ukraine
#    Date: (No date found)
#    News: Ukraine says it hit the bridge with underwater explosives - the crossing was built by Russia after it annexed the Crimean Peninsula. The two warring sides remain far apart on how to end the conflict after a second round of talks in Turkey. Footage shows attack drones homing in on their targets as they sit on the tarmac. The BBC's Paul Adams reflects on the impact of Ukraine's major drone attack on...
# 3. US & Canada
#    Link: https://www.bbc.com/news/us-canada
#    Date: (No date found)
#    News: Billionaire says the bill, which faces a key test in the Senate, undercuts efforts to slash federal spending. The law would aim to restrict asylum applications and expand authorities' ability to inspect mail. Community leaders say people are anxious after recent attacks in Boulder and Washington DC showed that “anyone, anywhere” could be targeted. Trump doubles down on his tariffs, while sparing t...
# 4. UK
#    Link: https://www.bbc.com/news/uk
#    Date: (No date found)
#    News: Chancellor Rachel Reeves says that more people will get winter fuel payment "this winter", but details of who is eligible remain unclear. Patients who died at Castle Hill Hospital near Hull may have suffered avoidable harm, documents suggest. Greg Monks was reported missing in Albufeira last week after travelling to the resort for a stag party. Marcus Monzo is on trial accused of murdering Daniel ...
# 5. Africa
#    Link: https://www.bbc.com/news/world/africa
#    Date: (No date found)
#    News: The BBC tracks down people close to the alleged crime kingpin who escaped custody while awaiting trial. Charlene Ruto accused the author of "misusing" her name by writing the book without seeking her permission. A female suicide bomber and an accomplice were "intercepted and neutralized", the army says. Boniface Mwangi says he has decided to speak despite the "shame and guilt" of being "sexually t...
# 6. Asia
#    Link: https://www.bbc.com/news/world/asia
#    Date: (No date found)
#    News: The 17-year-old's murder has sparked a debate about women on social media in Pakistan. Experts say he faces a challenging task, as division and discontentment continue to rack South Korea. Lee Jae-myung was voted in exactly six months after his predecessor made a failed martial law bid. Shubhanshu Shukla will be only the second Indian to travel to space and the first-ever to visit ISS. Known as Mr...
# 7. Australia
#    Link: https://www.bbc.com/news/world/australia
#    Date: (No date found)
#    News: Erin Patterson is accused of murdering three relatives and trying to kill another with poisonous fungi. Erin Patterson, who has pleaded not guilty, is accused of intentionally poisoning four relatives. Oscar Piastri leads Lando Norris to a McLaren one-two at the Spanish Grand Prix with Red Bull's Max Verstappen handed a 10-second penalty after late controversy. An inquest is examining whether ther...
# 8. Europe
#    Link: https://www.bbc.com/news/world/europe
#    Date: (No date found)
#    News: It's the latest setback for the world's most popular porn site, which is also under investigation by the EU. The German city cordons off a huge area, calling it the largest evacuation since the end of World War Two. Karol Nawrocki's new role is largely ceremonial, but he could still have a profound impact on Poland, including an early election. Footage shows clouds of dark coloured smoke and ash b...
# 9. Latin America
#    Link: https://www.bbc.com/news/world/latin_america
#    Date: (No date found)
#    News: Hugo Aguilar, who has long fought for indigenous rights, looks set to preside over Mexico's highest court. Investigators accuse the man of having given the order to kill the members of Grupo Fugitivo. The Colombian pop star says she is "devastated", after also cancelling her previous show in Boston. It was found that a judge involved in the case had taken part in a show about the trial. Saúl Lucia...
# 10. Middle East
#    Link: https://www.bbc.com/news/world/middle_east
#    Date: (No date found)
#    News: The president of the ICRC tells the BBC's international editor Jeremy Bowen that Palestinians have been stripped of human dignity. Mirjana Spoljaric has appealed to world leaders to intervene in the conflict in Gaza. The corporation says claims that a story was removed from its website are "completely wrong". Western diplomats are looking on with dismay at the killing of hungry Gazans near aid hub...
# 11. In Pictures
#    Link: https://www.bbc.com/news/in_pictures
#    Date: (No date found)
#    News: A selection of some of the most striking sports photographs taken around the world over the past seven days. Monday was the first of a packed two-day visit meant to highlight Canada's sovereignty and its ties to the Crown. Andrew Fusek Peters has spent a decade capturing the images in a celebration of Britain's wildife. A collection of images of Pembrokeshire from west Wales photographer, Mike Ale...
# 12. BBC InDepth
#    Link: https://www.bbc.com/news/bbcindepth
#    Date: (No date found)
#    News: To some, it’s a smart opportunity. To others there are security concerns. But either way, is there a playbook? The US president's ramped-up threats are seen by many as an attempt to reshape a stronghold of the left. Could he succeed? BBC's Laura Kuenssberg examines what we can expect from the strategic defence review - and its potential pitfalls. Tory leader Kemi Badenoch has made missteps that ar...
# 13. BBC Verify
#    Link: https://www.bbc.com/news/bbcverify
#    Date: (No date found)
#    News: BBC Verify examines three deadly incidents which left dozens dead near a controversial aid site in Gaza. Touted as a vital lifeline for Gazans facing  starvation, the first week of the new plan has been beset by chaos. Israel says its reopened access for a limited number of aid trucks into Gaza, after blocking supplies from entering the territory for the last 11 weeks. BBC Verify has been looking ...
# 14. Israel-Gaza War
#    Link: https://www.bbc.com/news/topics/c2vdnvdg6xxt
#    Date: (No date found)
#    News: Aid distribution will be halted on Wednesday, with Gazans warned by the IDF not to travel to collection points. Civilians were fired at by tanks, drones and helicopters, civil defence officials say, while Israel says only that troops fired towards several suspects. Hamdi al-Najjar's wife and 11-year-old son Adam, who was severely injured, are the only survivors in their family. Reports say an inci...
# 15. War in Ukraine
#    Link: https://www.bbc.com/news/war-in-ukraine
#    Date: (No date found)
#    News: Ukraine says it hit the bridge with underwater explosives - the crossing was built by Russia after it annexed the Crimean Peninsula. The two warring sides remain far apart on how to end the conflict after a second round of talks in Turkey. Footage shows attack drones homing in on their targets as they sit on the tarmac. The BBC's Paul Adams reflects on the impact of Ukraine's major drone attack on...
# 16. US & Canada
#    Link: https://www.bbc.com/news/us-canada
#    Date: (No date found)
#    News: Billionaire says the bill, which faces a key test in the Senate, undercuts efforts to slash federal spending. The law would aim to restrict asylum applications and expand authorities' ability to inspect mail. Community leaders say people are anxious after recent attacks in Boulder and Washington DC showed that “anyone, anywhere” could be targeted. Trump doubles down on his tariffs, while sparing t...
# 17. UK
#    Link: https://www.bbc.com/news/uk
#    Date: (No date found)
#    News: Rachel Reeves says more people will get winter fuel payment "this winter", but details over how many will get it remain unclear. Patients who died at Castle Hill Hospital near Hull may have suffered avoidable harm, documents suggest. Greg Monks was reported missing in Albufeira last week after travelling to the resort for a stag party. Marcus Monzo is on trial accused of murdering Daniel Anjorin 1...
# 18. UK Politics
#    Link: https://www.bbc.com/news/politics
#    Date: (No date found)
#    News: The chancellor defends her decisions and confirmed winter fuel payments will be restored to some pensioners this year. Chancellor Rachel Reeves says that more people will get winter fuel payment "this winter", but details of who is eligible remain unclear. Two senior government watchdogs say victim support services are being "pushed to the brink". Sir Keir Starmer is under pressure to raise defenc...
# 19. England
#    Link: https://www.bbc.com/news/england
#    Date: (No date found)
#    News: Marcus Monzo is on trial accused of murdering Daniel Anjorin 14, in Hainault last year. A review into the death of Abiyah Yasharahyalah, 3, said council teams lacked curiosity in his case. The Liverpool City Council review comes after 109 people were hurt when a car ploughed into crowds. Clive Betts says Dejphon Chansiri must find a buyer to avoid "the complete collapse of the club". Graham Gouldm...
# 20. N. Ireland
#    Link: https://www.bbc.com/news/northern_ireland
#    Date: (No date found)
#    News: Tina Satchwell, who was 45, was murdered by Richard Satchwell in March 2017. The 31 year-old man was arrested on Tuesday following the death of Marie Green, who was 71 years old. His family says they are entitled to have "any and all" information about his murder held by authorities. Staff and pupils from the former school of Dior's new creative director celebrate his success. Katie Mitchell, who ...
# 21. N. Ireland Politics
#    Link: https://www.bbc.com/news/northern_ireland/northern_ireland_politics
#    Date: (No date found)
#    News: Next week the government will lay out funding for the devolved nations for the next three years. The former Sinn Féin MP remains a member of the party and said her relationship with Michelle O'Neill is "okay". Politicians call for a strong response after masonry was thrown at homes in north Belfast. McMonagle was jailed last year for child sex offences and had worked as a party press officer. Ther...
# 22. Scotland
#    Link: https://www.bbc.com/news/scotland
#    Date: (No date found)
#    News: Greg Monks was reported missing in Albufeira last week after travelling to the resort for a stag party. Police Scotland is speaking out after speculation linking the weekend's murders with a gang war across Glasgow and Edinburgh. The chicks died after a male bird left their nest near Peebles in the Borders and two females struggled to feed them. The device, which was designed to help sailors set t...
# 23. Scotland Politics
#    Link: https://www.bbc.com/news/scotland/scotland_politics
#    Date: (No date found)
#    News: Voters speak ahead of a by-election to determine who replaces Christina McKelvie as MSP for Hamilton, Larkhall and Stonehouse. The prime minister insists it is more important to focus on the economy than the constitution. The Army needs to become "10 times more lethal" to face a "new era of threats", defence secretary says. The prime minister's plans mean significant changes in the way the UK fund...
# 24. Wales
#    Link: https://www.bbc.com/news/wales
#    Date: (No date found)
#    News: Parcels labelled as Yankee Candles were found to contain more than 300kg of cannabis. Elen Hughes, who lost her son Danial at 37-and-a-half weeks, says police guidance is "terrible". Learners at Denbigh High School were sent home after "historical chemicals" were found in a cupboard. Rail cash could be en-route to Wales next week, but rail money that's not will keep causing a row. After a disappoi...
# 25. Wales Politics
#    Link: https://www.bbc.com/news/wales/wales_politics
#    Date: (No date found)
#    News: Rail cash could be en-route to Wales next week, but rail money that's not will keep causing a row. It is wrong to charge people to enter the Big Pit National Coal Museum mine, a Senedd report says. The deputy first minister is in selection battle in seat spanning Port Talbot and Rhondda. First Minister Eluned Morgan takes questions in the Senedd. Wales had been the only part of the UK not to have ...
# 26. Africa
#    Link: https://www.bbc.com/news/world/africa
#    Date: (No date found)
#    News: The BBC tracks down people close to the alleged crime kingpin who escaped custody while awaiting trial. Charlene Ruto accused the author of "misusing" her name by writing the book without seeking her permission. A female suicide bomber and an accomplice were "intercepted and neutralized", the army says. Boniface Mwangi says he has decided to speak despite the "shame and guilt" of being "sexually t...
# 27. Asia
#    Link: https://www.bbc.com/news/world/asia
#    Date: (No date found)
#    News: The 17-year-old's murder has sparked a debate about women on social media in Pakistan. Experts say he faces a challenging task, as division and discontentment continue to rack South Korea. Lee Jae-myung was voted in exactly six months after his predecessor made a failed martial law bid. Shubhanshu Shukla will be only the second Indian to travel to space and the first-ever to visit ISS. Known as Mr...
# 28. China
#    Link: https://www.bbc.com/news/world/asia/china
#    Date: (No date found)
#    News: To some, it’s a smart opportunity. To others there are security concerns. But either way, is there a playbook? Yunqing Jian and Zunyong Liu allegedly brought into the US a fungus which damages a variety of crops and is toxic to humans and animals. The souring relationship between the nations has already caused issues for students at home and in the US. The Public Labour Prosecutor's Office in the ...
# 29. India
#    Link: https://www.bbc.com/news/world/asia/india
#    Date: (No date found)
#    News: Shubhanshu Shukla will be only the second Indian to travel to space and the first-ever to visit ISS. India legend Virat Kohli finally wins the Indian Premier League as Royal Challengers sealed their maiden title with a six-run win over Punjab Kings. Antibiotics are overused by some and out of reach for others - fuelling resistance and leaving deadly gaps in care. The bird had escaped from a farm i...
# 30. Australia
#    Link: https://www.bbc.com/news/world/australia
#    Date: (No date found)
#    News: Erin Patterson is accused of murdering three relatives and trying to kill another with poisonous fungi. Erin Patterson, who has pleaded not guilty, is accused of intentionally poisoning four relatives. Oscar Piastri leads Lando Norris to a McLaren one-two at the Spanish Grand Prix with Red Bull's Max Verstappen handed a 10-second penalty after late controversy. An inquest is examining whether ther...
# 31. Europe
#    Link: https://www.bbc.com/news/world/europe
#    Date: (No date found)
#    News: It's the latest setback for the world's most popular porn site, which is also under investigation by the EU. The German city cordons off a huge area, calling it the largest evacuation since the end of World War Two. Karol Nawrocki's new role is largely ceremonial, but he could still have a profound impact on Poland, including an early election. Footage shows clouds of dark coloured smoke and ash b...
# 32. Latin America
#    Link: https://www.bbc.com/news/world/latin_america
#    Date: (No date found)
#    News: Hugo Aguilar, who has long fought for indigenous rights, looks set to preside over Mexico's highest court. Investigators accuse the man of having given the order to kill the members of Grupo Fugitivo. The Colombian pop star says she is "devastated", after also cancelling her previous show in Boston. It was found that a judge involved in the case had taken part in a show about the trial. Saúl Lucia...
# 33. Middle East
#    Link: https://www.bbc.com/news/world/middle_east
#    Date: (No date found)
#    News: The president of the ICRC tells the BBC's international editor Jeremy Bowen that Palestinians have been stripped of human dignity. Mirjana Spoljaric has appealed to world leaders to intervene in the conflict in Gaza. The corporation says claims that a story was removed from its website are "completely wrong". Western diplomats are looking on with dismay at the killing of hungry Gazans near aid hub...
# 34. In Pictures
#    Link: https://www.bbc.com/news/in_pictures
#    Date: (No date found)
#    News: A selection of some of the most striking sports photographs taken around the world over the past seven days. Monday was the first of a packed two-day visit meant to highlight Canada's sovereignty and its ties to the Crown. Andrew Fusek Peters has spent a decade capturing the images in a celebration of Britain's wildife. A collection of images of Pembrokeshire from west Wales photographer, Mike Ale...
# 35. BBC InDepth
#    Link: https://www.bbc.com/news/bbcindepth
#    Date: (No date found)
#    News: To some, it’s a smart opportunity. To others there are security concerns. But either way, is there a playbook? The US president's ramped-up threats are seen by many as an attempt to reshape a stronghold of the left. Could he succeed? BBC's Laura Kuenssberg examines what we can expect from the strategic defence review - and its potential pitfalls. Tory leader Kemi Badenoch has made missteps that ar...
# 36. BBC Verify
#    Link: https://www.bbc.com/news/bbcverify
#    Date: (No date found)
#    News: BBC Verify examines three deadly incidents which left dozens dead near a controversial aid site in Gaza. Touted as a vital lifeline for Gazans facing  starvation, the first week of the new plan has been beset by chaos. Israel says its reopened access for a limited number of aid trucks into Gaza, after blocking supplies from entering the territory for the last 11 weeks. BBC Verify has been looking ...
# 37. LIVEGaza worse than hell on Earth, International Red Cross chief tells BBC as aid centres close for dayThe president of the ICRC tells the BBC's international editor Jeremy Bowen that Palestinians have been stripped of human dignity.
#    Link: https://www.bbc.com/news/live/cvg5vyp33j1t
#    Date: (No date found)
#    News: Caroline HawleyDiplomatic correspondent Mandy Blackman has been treating patients in Gaza I’ve been speaking to the nurse in charge of UK-Med’s field hospital in al-Mawasi, which treated 30 patients from yesterday’s shooting near an aid distribution site. Mandy Blackman says they were mostly men because of the strength needed for people to walk miles to pick up their food, and then carry their box...
# 38. South Korea's new president has a Trump-shaped crisis to avertLee Jae-myung secured a storming victory, but his honeymoon will barely last the day.13 hrs agoAsia
#    Link: https://www.bbc.com/news/articles/cpvkxxerln1o
#    Date: 2025-06-04 01:25:27 UTC
#    News: South Korea's new president, Lee Jae-myung, has secured a storming victory, but his honeymoon will barely last the day. The former opposition leader is not getting to enjoy the two-month transition period usually afforded to new leaders, so they can build their team and nail down their vision for the country. Instead he is entering office immediately, to fill the hole left by the impeachment of th...
# 39. The Indian pilot set for a historic space journey on Axiom-4Shubhanshu Shukla will be only the second Indian to travel to space and the first-ever to visit ISS.16 hrs agoWorld
#    Link: https://www.bbc.com/news/articles/ce80glkl7nno
#    Date: 2025-06-03 22:01:53 UTC
#    News: The Axiom Mission 4 (Ax-4), set to take off from Nasa's Kennedy Space Center in Florida next week, will be piloted by an Indian as it soars towards the International Space Station (ISS). Group Captain Shubhanshu Shukla of the Indian air force is among the four-member multi-country crew of Ax-4 that will be spending two weeks on the ISS. The flight, scheduled for 10 June at 08:22 EDT (12:22GMT; 17:...
# 40. Vanuatu looks into revoking Andrew Tate's golden passportTate gained citizenship in the tiny Pacific state under a scheme that has allegedly been abused by criminals.8 hrs agoAsia
#    Link: https://www.bbc.com/news/articles/cm23k0r5395o
#    Date: 2025-06-04 05:59:53 UTC
#    News: Vanuatu authorities are looking at revoking Andrew Tate's citizenship after it was revealed that he acquired a golden passport at around the same time as his 2022 arrest in Romania for rape and human trafficking. The self-described misogynist influencer acquired citizenship under a fast-track scheme for those who invest at least $130,000 (£96,000) in the tiny Pacific archipelago, according to an i...
# 41. Cologne evacuates 20,000 so WW2 bombs can be defusedThe German city cordons off a huge area, calling it the largest evacuation since the end of World War Two.5 hrs agoEurope
#    Link: https://www.bbc.com/news/articles/cj6r04e870do
#    Date: 2025-06-04 08:48:35 UTC
#    News: The German city of Cologne is evacuating some 20,500 people from a large area in the city centre so experts can defuse three unexploded bombs from World War Two. The American bombs were discovered on Monday in a shipyard in the Deutz neighbourhood, the city said in a statement. Unexplodedordnance can still pose a danger and the city has sealed off the zone within a 1,000m (3,280ft) radius, in what...
# 42. South Korea's new president has a Trump-shaped crisis to avertLee Jae-myung secured a storming victory, but his honeymoon will barely last the day.13 hrs agoAsia
#    Link: https://www.bbc.com/news/articles/cpvkxxerln1o
#    Date: 2025-06-04 01:25:27 UTC
#    News: South Korea's new president, Lee Jae-myung, has secured a storming victory, but his honeymoon will barely last the day. The former opposition leader is not getting to enjoy the two-month transition period usually afforded to new leaders, so they can build their team and nail down their vision for the country. Instead he is entering office immediately, to fill the hole left by the impeachment of th...
# 43. South Korea's new president Lee Jae-myung pledges to 'unite' countryExperts say he faces a challenging task, as division and discontentment continue to rack South Korea.9 hrs agoAsia
#    Link: https://www.bbc.com/news/articles/cq549p1yd2eo
#    Date: 2025-06-04 05:15:57 UTC
#    News: Just hours after winning the South Korean presidency, Lee Jae-myung has pledged to "unite the people" in his inauguration speech on Wednesday. The 61-year-old won a snap election by 49.4% - a clear rejection of his rival, Kim Moon-soo, who came from the same party as impeached president Yoon Suk Yeol. Yoon triggered months of political chaos after he attempted to impose martial law, which eventual...
# 44. Deadly mushroom lunch cook tells court she threw up toxic mealErin Patterson is accused of murdering three relatives and trying to kill another with poisonous fungi.6 hrs agoAustralia
#    Link: https://www.bbc.com/news/articles/c5yx7vewn75o
#    Date: 2025-06-04 07:46:00 UTC
#    News: An Australian woman on trial for murder says she threw up the toxic mushroom meal which killed her relatives, after binge eating dessert. Erin Patterson has pleaded not guilty to four charges - three of murder and one of attempted murder - over the beef Wellington lunch at her regional Victorian house in July 2023. Prosecutors allege Ms Patterson deliberately served toxic death cap mushrooms, but ...
# 45. Teen TikTok star shot dead after man broke into her home, police sayThe 17-year-old's murder has sparked a debate about women on social media in Pakistan.2 hrs agoAsia
#    Link: https://www.bbc.com/news/articles/c4g7v1evrmdo
#    Date: 2025-06-04 11:38:54 UTC
#    News: A 22-year-old man has been arrested in Pakistan and confessed to the murder of 17-year-old social media influencer Sana Yousaf, according to police. Authorities say they believe Umar Hayat murdered Ms Yousaf at her home in Islamabad on Monday after she rejected what they called his "offers of friendship". He allegedly also repeatedly tried and failed, to meet her. They say he broke into her home, ...
# 46. The Indian pilot set for a historic space journey on Axiom-4Shubhanshu Shukla will be only the second Indian to travel to space and the first-ever to visit ISS.16 hrs agoWorld
#    Link: https://www.bbc.com/news/articles/ce80glkl7nno
#    Date: 2025-06-03 22:01:53 UTC
#    News: The Axiom Mission 4 (Ax-4), set to take off from Nasa's Kennedy Space Center in Florida next week, will be piloted by an Indian as it soars towards the International Space Station (ISS). Group Captain Shubhanshu Shukla of the Indian air force is among the four-member multi-country crew of Ax-4 that will be spending two weeks on the ISS. The flight, scheduled for 10 June at 08:22 EDT (12:22GMT; 17:...
# 47. LIVEUS markets open higher as businesses brace for impact of Trump's 50% metals tariffs
#    Link: https://www.bbc.com/news/live/c308v53v4e6t
#    Date: (No date found)
#    News: Natalie ShermanNew York business reporter Shares in the US have opened for trading, and investors do not appear worried that the tariffs are moving ahead. The Dow Jones Industrial Average is up about 0.2%, the S&P 500 has risen 0.3% and the Nasdaq is trading nearly 0.5% higher. That relatively muted reaction masks the big moves for some specific companies that followed Trump’s announcement of his ...
# 48. Musk calls Trump's tax bill a 'disgusting abomination' 3 hrs agoUS & Canada
#    Link: https://www.bbc.com/news/articles/c0j76djzgpvo
#    Date: 2025-06-04 11:08:17 UTC
#    News: Elon Musk has hit out at President Donald Trump's signature tax and spending bill, describing it as a "disgusting abomination", in a widening rift between the two. The tech billionaire posted on X that the bill would add to the US budget deficit and saddle Americans with "crushing" debt. The budget, which includes huge tax breaks and more defence spending, was passed by the House of Representative...
# 49. Chinese nationals accused of smuggling 'dangerous biological pathogen' into US19 hrs agoWorld
#    Link: https://www.bbc.com/news/articles/c4gkdppymk4o
#    Date: 2025-06-03 18:41:13 UTC
#    News: Two Chinese nationals have been accused of smuggling a fungus into the US that officials describe as a "dangerous biological pathogen". Yunqing Jian, 33, and Zunyong Liu, 34, have been charged with conspiracy, smuggling goods, false statements, and visa fraud, the US Attorney's Office for the Eastern District of Michigan announced on Tuesday. The complaint alleges Mr Liu tried to smuggle the fungu...
# 50. LIVEBBC Verify Live: New satellite images show damaged Russian bombers from Ukraine attack
#    Link: https://www.bbc.com/news/live/cx2xrz4yqvwt
#    Date: (No date found)
#    News: Paul BrownBBC Verify senior journalist We've been analysing the latest satellite imagery of a Russian air basefollowing Sunday's Ukrainian drone attack to get a picture of how much damage was done. Satellite imaging is
# a key tool for us because it offers a
# birds-eye view of what is happening at a given
# location – especially from places where we can’t send journalists because
# it’s either too danger...
# 51. Meghan shares new photos of Lilibet to mark fourth birthday4 hrs agoUK
#    Link: https://www.bbc.com/news/articles/cewd79ey270o
#    Date: 2025-06-04 09:34:45 UTC
#    News: The Duchess of Sussex has posted intimate family photos of Princess Lilibet to mark her fourth birthday. Meghan shared a black-and-white snap of her cuddling her daughter, who is sitting on her lap, with the pair both sporting windswept hair, appearing to be on a boat. The second image shows Meghan tenderly cradling the princess as a newborn following her birth in 2021. Meghan wrote on Instagram: ...
# 52. Watch: BBC on the ground in Seoul as new president is announcedOpposition's Lee Jae-myung will become South Korea's next president, winning the country's first election since impeachment chaos.19 hrs agoAsia
#    Link: https://www.bbc.com/news/videos/cn7z8kgj2z0o
#    Date: 2025-06-03 18:30:36 UTC
#    News: Millions voted in Tuesday's snap election triggered by former president Yoon Suk Yeol's impeachment over his failed martial law bid. Kim Moon-soo of the People Power Party conceded defeat and congratulated Lee Jae-myung, who had fought this election as a referendum on martial law – promising to make sure it would never happen again. The BBC's Jean Mackenzie reports from a Democratic Party victory ...
# 53. Simon Jack: Tariff relief for UK but new clock ticking on US dealIf the UK's deal with the US is not finalised by 9 July, the UK's tariff on steel will go back up to 50%. 4 hrs agoBusiness
#    Link: https://www.bbc.com/news/articles/cwy6xz76z32o
#    Date: 2025-06-04 10:04:32 UTC
#    News: It is hard to argue the UK exemption from the doubling of US tariffs on imported steel from 25 to 50% is not good news. It was not a given that the UK would get this carve-out despite having done a deal on 8 May to reduce tariffs on the metals to zero. That agreement is not yet in force, however, and speaking to steel industry leaders and government officials right up until Tuesday night's announc...
# 54. Why Labour is strengthening ties with China after years of rollercoaster relationsTo some, it’s a smart opportunity. To others there are security concerns. But either way, is there a playbook?14 hrs agoBBC InDepth
#    Link: https://www.bbc.com/news/articles/c071jr159p0o
#    Date: 2025-06-04 00:16:25 UTC
#    News: Listen to Ankur read this article The sprawling city of Chongqing in southwestern China is an incredible sight. Built on mountainous terrain and crisscrossed by rivers, it is connected by vast elevated roads. Trains even run through some buildings. TikTokers have begun documenting their commutes in the striking urban architecture, generating millions of likes and much hype. But it is also where, o...
# 55. Two Scots were shot dead in a busy Spanish bar. Holidaymakers are frightenedBrits on holiday in the Costa del Sol have been shaken by the murder of two senior underworld figures.21 hrs agoScotland
#    Link: https://www.bbc.com/news/articles/ckgr9r4zezro
#    Date: 2025-06-03 16:49:04 UTC
#    News: It's less than 36 hours after a gangland double murder in a busy bar on the Costa Del Sol, and there is no sign of the Spanish police - apart from an occasional patrol car gliding by. No cordon, no tape, no forensics in white suits, no officer guarding the front door of Monaghans Bar in Fuengirola. According to a local cameraman, it was the same on Sunday afternoon - the day after Ross Monaghan an...
# 56. 'I begged for help, but only God answered': Growing dangers of pregnancy and childbirth in GazaRather than representing the hope of new life, babies in Gaza have come to epitomise the struggle to survive.1 day agoMiddle East
#    Link: https://www.bbc.com/news/articles/c626ljrp21yo
#    Date: 2025-06-03 10:20:53 UTC
#    News: Amid a deadly war in Gaza, new lives begin. But newborn babies and those still in the womb are among the worst hit by the harsh conditions. With acute shortages of food, the UN says that one in 10 new babies is underweight or premature. There has also been an increase in miscarriages, stillbirths and congenital abnormalities. At Nasser hospital in the southern city of Khan Younis, Malak Brees, now...
# 57. Simon Jack: Tariff relief for UK but new clock ticking on US dealIf the UK's deal with the US is not finalised by 9 July, the UK's tariff on steel will go back up to 50%. 4 hrs agoBusiness
#    Link: https://www.bbc.com/news/articles/cwy6xz76z32o
#    Date: 2025-06-04 10:04:32 UTC
#    News: It is hard to argue the UK exemption from the doubling of US tariffs on imported steel from 25 to 50% is not good news. It was not a given that the UK would get this carve-out despite having done a deal on 8 May to reduce tariffs on the metals to zero. That agreement is not yet in force, however, and speaking to steel industry leaders and government officials right up until Tuesday night's announc...
# 58. On the hunt for Tiger, the fugitive linked to illegal South African gold mine where 78 diedThe BBC tracks down people close to the alleged crime kingpin who escaped custody while awaiting trial.15 hrs agoAfrica
#    Link: https://www.bbc.com/news/articles/cvg5k518gq2o
#    Date: 2025-06-03 23:07:36 UTC
#    News: Nobody in South Africa seems to know where Tiger is. The 42-year-old from neighbouring Lesotho, whose real name is James Neo Tshoaeli, has evaded a police manhunt for the past four months. Detained after being accused of controlling the illegal operations at an abandoned gold mine near Stilfontein in South Africa, where 78 corpses were discovered underground in January, Tiger escaped custody, poli...
# 59. The Indian pilot set for a historic space journey on Axiom-4Shubhanshu Shukla will be only the second Indian to travel to space and the first-ever to visit ISS.16 hrs agoWorld
#    Link: https://www.bbc.com/news/articles/ce80glkl7nno
#    Date: 2025-06-03 22:01:53 UTC
#    News: The Axiom Mission 4 (Ax-4), set to take off from Nasa's Kennedy Space Center in Florida next week, will be piloted by an Indian as it soars towards the International Space Station (ISS). Group Captain Shubhanshu Shukla of the Indian air force is among the four-member multi-country crew of Ax-4 that will be spending two weeks on the ISS. The flight, scheduled for 10 June at 08:22 EDT (12:22GMT; 17:...
# 60. Why Labour is strengthening ties with China after years of rollercoaster relationsTo some, it’s a smart opportunity. To others there are security concerns. But either way, is there a playbook?14 hrs agoBBC InDepth
#    Link: https://www.bbc.com/news/articles/c071jr159p0o
#    Date: 2025-06-04 00:16:25 UTC
#    News: Listen to Ankur read this article The sprawling city of Chongqing in southwestern China is an incredible sight. Built on mountainous terrain and crisscrossed by rivers, it is connected by vast elevated roads. Trains even run through some buildings. TikTokers have begun documenting their commutes in the striking urban architecture, generating millions of likes and much hype. But it is also where, o...
# 61. 1Watch: Canada wildfire smoke drifts into US and across the Atlantic
#    Link: https://www.bbc.com/news/videos/c20n3dw2ee6o
#    Date: 2025-06-03 20:29:53 UTC
#    News: Smoke from various active wildfires in Canada has been spreading south into the US, affecting air quality in many states, including Minnesota. Maps and satellite imagery show the large-scale impact of the blazes, as smoke also drifts East across the Atlantic Ocean. At least 3.4 million acres (1.4m hectares) have burned nationwide amid unusually hot, dry conditions. Flames burning in Manitoba have ...
# 62. 2Watch: Searching derelict and desolate area in Madeleine McCann case
#    Link: https://www.bbc.com/news/videos/cwywkv1gj7lo
#    Date: 2025-06-04 09:02:33 UTC
#    News: The BBC's Phil Mackie reports from Lagos near Praia da Luz, Portugal where Portuguese and German police are continuing in their search for Madeleine McCann. As Mackie reports "the clock is ticking" forinvestigators who only have until Fridayto search across a 21 sq km (8.1 sq miles) site between where the toddler went missing and where the German investigators' prime suspect, Christian Brückner, h...
# 63. 3'We are all going to die' - Senator's healthcare comment sparks row
#    Link: https://www.bbc.com/news/videos/czdy7j51517o
#    Date: 2025-06-03 23:09:14 UTC
#    News: During a town hall meeting in Iowa, Senator Joni Ernst addressed an audience member's concerns about reduced spending on Medicaid in President Donald Trump's Big Beautiful Bill Act by saying: "We are all going to die." The senator went on to post a tongue-in-cheek video from a cemetery saying she made an incorrect assumption that everyone in the auditorium "understood that, yes, we are all going t...
# 64. 4Nepal's urban rhinos that won't return to the wild
#    Link: https://www.bbc.com/news/videos/cpw7jy4p7zko
#    Date: 2025-06-04 05:50:19 UTC
#    News: More stories from Asia. Copyright 2025 BBC. All rights reserved.TheBBCisnot responsible for the content of external sites.Read about our approach to external linking.
# 65. 5The Today Debate: Israel-Gaza - are we witnessing war crimes?
#    Link: https://www.bbc.com/news/videos/c365rkj2wr7o
#    Date: 2025-06-03 21:21:33 UTC
#    News: The BBC's Anna Foster hosts a special Today Debate: Israel-Gaza - are we witnessing war crimes? On the panel are Lyse Doucet, the BBC's chief international correspondent, and Michael Kleiner, president of the Supreme Court of the Israeli Likud party. We also hear from Afif Safieh, who was involved in talks that led to the first official US-Palestinian dialogue, and Baroness Helena Kennedy, Labour ...
# 66. Vanuatu looks into revoking Andrew Tate's golden passportTate gained citizenship in the tiny Pacific state under a scheme that has allegedly been abused by criminals.8 hrs agoAsia
#    Link: https://www.bbc.com/news/articles/cm23k0r5395o
#    Date: 2025-06-04 05:59:53 UTC
#    News: Vanuatu authorities are looking at revoking Andrew Tate's citizenship after it was revealed that he acquired a golden passport at around the same time as his 2022 arrest in Romania for rape and human trafficking. The self-described misogynist influencer acquired citizenship under a fast-track scheme for those who invest at least $130,000 (£96,000) in the tiny Pacific archipelago, according to an i...
# 67. Japanese baseball legend Shigeo Nagashima dies aged 89Known as Mr Giants, Nagashima was one of Japan's most famous sports stars during the 1960s and 70s.1 day agoAsia
#    Link: https://www.bbc.com/news/articles/c20xqx88137o
#    Date: 2025-06-03 12:09:32 UTC
#    News: Former baseball player Shigeo Nagashima, who was once one of Japan's most famous sports stars, has died aged 89. He died of pneumonia at a hospital in Tokyo, according to a statement released by his former team the Yomiuri Giants. Nicknamed Mr Giants, Nagashima won nine straight titles with the team in the 1960s and 70s, playing in 2,186 games and hitting 444 home runs. Commenting on his death, a ...
# 68. Body found in search for stag party Scot missing in PortugalGreg Monks was reported missing in Albufeira last week after travelling to the resort for a stag party.1 hr agoGlasgow & West Scotland
#    Link: https://www.bbc.com/news/articles/ce9vm9z3579o
#    Date: 2025-06-04 12:36:11 UTC
#    News: A body has been found in the search for a Scottish man reported missing in Portugal. Greg Monks, 38, was reported missing last week after leaving the main strip in Albufeira in the Algarve in the early hours of Wednesday morning. Mr Monks, from Cambuslang, near Glasgow, had travelled to the resort on 27 May on a stag party with friends. The Portuguese national Policia Judiciaria said the body of a...
# 69. India anger over 10-year-old rape victim's death after alleged treatment delayFamily members allege that the girl was kept waiting in an ambulance for hours before being admitted to the hospital.1 day agoAsia
#    Link: https://www.bbc.com/news/articles/cn0gzp0wlrno
#    Date: 2025-06-03 08:29:04 UTC
#    News: The death of a 10-year-old rape victim in the eastern Indian state of Bihar after an alleged delay in medical treatment has sparked outrage in the country. The girl died on Sunday morning at the state government-run Patna Medical College and Hospital (PMCH) in the capital Patna. Her uncle has alleged that the child's condition worsened as she was kept waiting in an ambulance for around four hours ...
# 70. Kenyan author prosecuted for writing a book about president's daughterCharlene Ruto accused the author of "misusing" her name by writing the book without seeking her permission.4 hrs agoAfrica
#    Link: https://www.bbc.com/news/articles/ckgnrlp6vgzo
#    Date: 2025-06-04 10:00:52 UTC
#    News: Kenyan free-speech advocates and lawyers have condemned the prosecution of the author of an unauthorised biography of Kenyan President William Ruto's daughter. Charlene Ruto accused Webster Ochora Elijah of "misusing" her name by writing the book without first seeking permission from her. On Tuesday, the author was arrested and charged with impersonation over the book titled Beyond the Name: Charl...
# 71. Japanese baseball legend Shigeo Nagashima dies aged 89Known as Mr Giants, Nagashima was one of Japan's most famous sports stars during the 1960s and 70s.1 day agoAsia
#    Link: https://www.bbc.com/news/articles/c20xqx88137o
#    Date: 2025-06-03 12:09:32 UTC
#    News: Former baseball player Shigeo Nagashima, who was once one of Japan's most famous sports stars, has died aged 89. He died of pneumonia at a hospital in Tokyo, according to a statement released by his former team the Yomiuri Giants. Nicknamed Mr Giants, Nagashima won nine straight titles with the team in the 1960s and 70s, playing in 2,186 games and hitting 444 home runs. Commenting on his death, a ...
# 72. TikTok blocks searches for extreme thinness 'skinnytok' hashtagThe app acknowledged the viral hashtag had been become linked to "unhealthy weight loss content."2 hrs agoTechnology
#    Link: https://www.bbc.com/news/articles/c4gr6q6256do
#    Date: 2025-06-04 11:36:22 UTC
#    News: TikTok is preventing users searching for "skinnytok" - a hashtag which critics say directs people towards content which "idolises extreme thinness." Content associated with the hashtag includes videos showing people's work-out routines or what they eat in a day. TikTok said it had "blocked search results for #skinnytok since it has become linked to unhealthy weight loss content." People using the ...
# 73. Tesla is 'not interested' in producing cars in India - ministerThis is the first time India has publicly admitted that it has not been able to lure investment dollars from Musk. 1 day agoAsia
#    Link: https://www.bbc.com/news/articles/ce9vm07k0y7o
#    Date: 2025-06-03 06:32:51 UTC
#    News: Elon Musk-owned electric vehicle (EV) giant Tesla is "not interested in manufacturing in India", the country's heavy industries minister has said. The remarks were made on Monday as the Indian government issued detailed guidelines for a scheme to promote EV manufacturing in the country. This is the first time that India has publicly admitted that it has not been able to lure investment dollars fro...
# 74. Body found in search for stag party Scot missing in PortugalGreg Monks was reported missing in Albufeira last week after travelling to the resort for a stag party.1 hr agoGlasgow & West Scotland
#    Link: https://www.bbc.com/news/articles/ce9vm9z3579o
#    Date: 2025-06-04 12:36:11 UTC
#    News: A body has been found in the search for a Scottish man reported missing in Portugal. Greg Monks, 38, was reported missing last week after leaving the main strip in Albufeira in the Algarve in the early hours of Wednesday morning. Mr Monks, from Cambuslang, near Glasgow, had travelled to the resort on 27 May on a stag party with friends. The Portuguese national Policia Judiciaria said the body of a...
# 75. 1Teen TikTok star shot dead after man broke into her home, police say
#    Link: https://www.bbc.com/news/articles/c4g7v1evrmdo
#    Date: 2025-06-04 11:38:54 UTC
#    News: A 22-year-old man has been arrested in Pakistan and confessed to the murder of 17-year-old social media influencer Sana Yousaf, according to police. Authorities say they believe Umar Hayat murdered Ms Yousaf at her home in Islamabad on Monday after she rejected what they called his "offers of friendship". He allegedly also repeatedly tried and failed, to meet her. They say he broke into her home, ...
# 76. 2Meghan shares new photos of Lilibet to mark fourth birthday
#    Link: https://www.bbc.com/news/articles/cewd79ey270o
#    Date: 2025-06-04 09:34:45 UTC
#    News: The Duchess of Sussex has posted intimate family photos of Princess Lilibet to mark her fourth birthday. Meghan shared a black-and-white snap of her cuddling her daughter, who is sitting on her lap, with the pair both sporting windswept hair, appearing to be on a boat. The second image shows Meghan tenderly cradling the princess as a newborn following her birth in 2021. Meghan wrote on Instagram: ...
# 77. 3Canada proposes sweeping immigration and security bill
#    Link: https://www.bbc.com/news/articles/c780rj9nve0o
#    Date: 2025-06-04 00:15:32 UTC
#    News: The Canadian government has proposed a bill to restrict some asylum claims and give authorities more power to halt the processing of immigration applications. Canada's immigration minister Lena Diab said the Strong Borders Act is meant to curb organised crime and the flow of illegal drugs and weapons, while boosting the "integrity" of the country's immigration system. It includes provisions that w...
# 78. 4Musk calls Trump's tax bill a 'disgusting abomination'
#    Link: https://www.bbc.com/news/articles/c0j76djzgpvo
#    Date: 2025-06-04 11:08:17 UTC
#    News: Elon Musk has hit out at President Donald Trump's signature tax and spending bill, describing it as a "disgusting abomination", in a widening rift between the two. The tech billionaire posted on X that the bill would add to the US budget deficit and saddle Americans with "crushing" debt. The budget, which includes huge tax breaks and more defence spending, was passed by the House of Representative...
# 79. 5South Korea's new president has a Trump-shaped crisis to avert
#    Link: https://www.bbc.com/news/articles/cpvkxxerln1o
#    Date: 2025-06-04 01:25:27 UTC
#    News: South Korea's new president, Lee Jae-myung, has secured a storming victory, but his honeymoon will barely last the day. The former opposition leader is not getting to enjoy the two-month transition period usually afforded to new leaders, so they can build their team and nail down their vision for the country. Instead he is entering office immediately, to fill the hole left by the impeachment of th...
# 80. 6Brits could face death over Bali drugs plot
#    Link: https://www.bbc.com/news/articles/cewd705yy74o
#    Date: 2025-06-03 12:09:40 UTC
#    News: A trial has begun of three British nationals alleged to have been involved with smuggling cocaine disguised as packets of Angel Delight into Indonesia. Jon Collyer, 38, and Lisa Stocker, 39, were arrested at Bali's international airport in February after being caught with 994g of cocaine, according to Balinese authorities. The pair appeared in court alongside Phineas Float, 31, who was allegedly d...
# 81. 7Vanuatu looks into revoking Andrew Tate's golden passport
#    Link: https://www.bbc.com/news/articles/cm23k0r5395o
#    Date: 2025-06-04 05:59:53 UTC
#    News: Vanuatu authorities are looking at revoking Andrew Tate's citizenship after it was revealed that he acquired a golden passport at around the same time as his 2022 arrest in Romania for rape and human trafficking. The self-described misogynist influencer acquired citizenship under a fast-track scheme for those who invest at least $130,000 (£96,000) in the tiny Pacific archipelago, according to an i...
# 82. 8Pornhub pulls out of France over age verification law
#    Link: https://www.bbc.com/news/articles/c5yelvlnzveo
#    Date: 2025-06-03 16:38:10 UTC
#    News: Aylo, the company which runs a number of pornographic websites, including Pornhub, is to stop operating in France from Wednesday. It is in reaction to a French law requiring porn sites to take extra steps to verify their users' ages. An Aylo spokesperson said the law was a privacy risk and assessing people's ages should be done at a device level. Pornhub is the most visited porn site in the world ...
# 83. 9Deadly mushroom lunch cook tells court she threw up toxic meal
#    Link: https://www.bbc.com/news/articles/c5yx7vewn75o
#    Date: 2025-06-04 07:46:00 UTC
#    News: An Australian woman on trial for murder says she threw up the toxic mushroom meal which killed her relatives, after binge eating dessert. Erin Patterson has pleaded not guilty to four charges - three of murder and one of attempted murder - over the beef Wellington lunch at her regional Victorian house in July 2023. Prosecutors allege Ms Patterson deliberately served toxic death cap mushrooms, but ...
# 84. 10The Indian pilot set for a historic space journey on Axiom-4
#    Link: https://www.bbc.com/news/articles/ce80glkl7nno
#    Date: 2025-06-03 22:01:53 UTC
#    News: The Axiom Mission 4 (Ax-4), set to take off from Nasa's Kennedy Space Center in Florida next week, will be piloted by an Indian as it soars towards the International Space Station (ISS). Group Captain Shubhanshu Shukla of the Indian air force is among the four-member multi-country crew of Ax-4 that will be spending two weeks on the ISS. The flight, scheduled for 10 June at 08:22 EDT (12:22GMT; 17:...

# %% [markdown]
# # Saving News in Markdown file

# %%
# save the headlines, links, and snippets to a markdown file
from datetime import datetime
import requests
from bs4 import BeautifulSoup

# URL for BBC News homepage
news_url = "https://www.bbc.com/news"

# Fetch and parse the page
response = requests.get(news_url)
news_soup = BeautifulSoup(response.content, "html.parser")

# Try multiple selectors for headlines
headlines = news_soup.find_all("h3", class_="gs-c-promo-heading__title")

# If not found, try anchor tags with class 'gs-c-promo-heading'
if not headlines:
    promo_anchors = news_soup.select("a.gs-c-promo-heading")
    headlines = [a for a in promo_anchors if a.text.strip()]

# If still not found, fallback to all anchor tags with '/news/' in href and non-empty text
if not headlines:
    headlines = [
        a for a in news_soup.find_all("a", href=True)
        if "/news/" in a["href"] and a.text.strip()
    ]

if not headlines:
    print("No headlines found using known selectors.")
else:
    # Get current date and time for filename
    now_str = datetime.now().strftime("%Y%m%d_%H%M%S")
    md_filename = f"bbc_headlines_{now_str}.md"

    with open(md_filename, "w") as f:
        for idx, headline in enumerate(headlines, start=1):
            headline_text = headline.text.strip()
            link = None
            if headline.name == "a" and headline.has_attr("href"):
                link = headline["href"]
            else:
                parent_a = headline.find_parent("a", href=True)
                if parent_a:
                    link = parent_a["href"]
            if link and link.startswith("/"):
                link = "https://www.bbc.com" + link

            # Fetch the news article page to get date and snippet
            date_str = ""
            snippet = ""
            if link:
                try:
                    article_resp = requests.get(link)
                    article_soup = BeautifulSoup(article_resp.content, "html.parser")
                    # Extract paragraphs for snippet
                    article_tag = article_soup.find("article")
                    if not article_tag:
                        article_tag = article_soup.find(attrs={"role": "main"})
                    if article_tag:
                        paragraphs = article_tag.find_all("p")
                    else:
                        paragraphs = article_soup.find_all("p")
                    article_text = " ".join([p.get_text(strip=True) for p in paragraphs])
                    snippet = article_text[:400] + ("..." if len(article_text) > 400 else "")
                    # Extract date
                    time_tag = article_soup.find("time")
                    if not time_tag:
                        meta_time = article_soup.find("meta", attrs={"property": "article:published_time"})
                        if meta_time and meta_time.has_attr("content"):
                            date_str = meta_time["content"]
                    if not date_str and time_tag and time_tag.has_attr("datetime"):
                        date_str = time_tag["datetime"]
                    elif not date_str and time_tag:
                        date_str = time_tag.get_text(strip=True)
                    if date_str:
                        try:
                            dt = datetime.fromisoformat(date_str.replace("Z", "+00:00"))
                            date_str = dt.strftime("%Y-%m-%d %H:%M:%S %Z")
                        except Exception:
                            pass
                except Exception:
                    snippet = "(Could not fetch article)"
                    date_str = ""
            f.write(f"{idx}. [{headline_text}]({link})\n")
            f.write(f"   Date: {date_str if date_str else '(No date found)'}\n")
            f.write(f"   News: {snippet}\n")

# %% [markdown]
# # Pakistan-India War 2025 from BBC News

# %%
import requests
from bs4 import BeautifulSoup
import re

# Search query for BBC
query = "pakistan india war"
# query = input("Enter search query: ")
# URL for BBC search
search_url = f"https://www.bbc.co.uk/search?q={query.replace(' ', '+')}"

response = requests.get(search_url)
soup = BeautifulSoup(response.content, "html.parser")

# Try to find all promo items (less dependent on class names)
results = []
pattern = re.compile(r"\bPakistan\b", re.IGNORECASE)
pattern2 = re.compile(r"\bIndia\b", re.IGNORECASE)

for item in soup.find_all(["article", "li"]):
    # Try to get headline and snippet
    headline_tag = item.find(["h1", "h2", "h3", "span"])
    snippet_tag = item.find("p")
    headline = headline_tag.get_text(strip=True) if headline_tag else ""
    snippet = snippet_tag.get_text(strip=True) if snippet_tag else ""
    # Check if both 'Pakistan' and 'India' are present in either headline or snippet
    if (pattern.search(headline) and pattern2.search(headline)) or \
       (pattern.search(snippet) and pattern2.search(snippet)):
        link_tag = item.find("a", href=True)
        link = link_tag["href"] if link_tag else ""
        if link and link.startswith("/"):
            link = "https://www.bbc.co.uk" + link
        results.append({
            "headline": headline,
            "snippet": snippet,
            "link": link
        })

if not results:
    print("No results found for 'Pakistan India war' on BBC.")
else:
    for idx, res in enumerate(results, 1):
        print(f"{idx}. {res['headline']}")
        print(f"   Link: {res['link']}")
        print(f"   Snippet: {res['snippet']}\n")
# Out:
# 1. How real is the risk of nuclear war between India and Pakistan?
#    Link: https://www.bbc.co.uk/news/articles/c2e373yzndro
#    Snippet: How real is the risk of nuclear war between India and Pakistan?
#
# 2. The first drone war opens a new chapter in India-Pakistan conflict
#    Link: https://www.bbc.co.uk/news/articles/cwy6w6507wqo
#    Snippet: The first drone war opens a new chapter in India-Pakistan conflict
#
# 3. The World Tonight. Can Pakistan and India avoid war? Listen NowThe World TonightCan Pakistan and India avoid war?
#    Link: https://www.bbc.co.uk/sounds/play/m002btyv
#    Snippet: The World Tonight. Can Pakistan and India avoid war? Listen NowThe World Tonight
#
# 4. The Briefing Room. Are India and Pakistan on the brink of war over Kashmir? Listen NowThe Briefing RoomAre India and Pakistan on the brink of war over Kashmir?
#    Link: https://www.bbc.co.uk/sounds/play/m002bj77
#    Snippet: The Briefing Room. Are India and Pakistan on the brink of war over Kashmir? Listen NowThe Briefing Room
#
# 5. Global News Podcast. Pakistan warns of imminent military strikes from India. Listen NowGlobal News PodcastPakistan warns of imminent military strikes from India
#    Link: https://www.bbc.co.uk/sounds/play/p0l7d3n4
#    Snippet: Global News Podcast. Pakistan warns of imminent military strikes from India. Listen NowGlobal News Podcast
#
# 6. How India and Pakistan share one of the world's most dangerous borders
#    Link: https://www.bbc.co.uk/news/articles/cgmj7l0lne3o
#    Snippet: How India and Pakistan share one of the world's most dangerous borders
#
# 7. The Explanation. The Media Show: Misinformation and the India-Pakistan Standoff. Listen NowThe ExplanationThe Media Show: Misinformation and the India-Pakistan Standoff
#    Link: https://www.bbc.co.uk/sounds/play/w3ct7yry
#    Snippet: The Explanation. The Media Show: Misinformation and the India-Pakistan Standoff. Listen NowThe Explanation
#
# 8. Why India could not stop IMF bailout to Pakistan
#    Link: https://www.bbc.co.uk/news/articles/c3v5r1erdpgo
#    Snippet: Why India could not stop IMF bailout to Pakistan
#
# 9. These five measures remain, despite the India-Pakistan ceasefire
#    Link: https://www.bbc.co.uk/news/articles/c17r04qp4xdo
#    Snippet: These five measures remain, despite the India-Pakistan ceasefire
#
# 10. Modi addresses nation for first time since start of India-Pakistan strikes
#    Link: https://www.bbc.co.uk/news/articles/cm26760pj13o
#    Snippet: Modi addresses nation for first time since start of India-Pakistan strikes
